# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Lekshmi\Documents\PANDAS PROJECT\Customer Call List.xlsx")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip("/")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip(".")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.rstrip("_")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# Not Working

df["Phone_Number"] = df["Phone_Number"].str.replace(r"[^a-zA-Z0-9]","",regex = True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x : str(x))
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          nan
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter          nan
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
# Step 1: Remove non-digit characters
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace(r'[^0-9]', '', regex=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
# Step 2: Make sure each number has at least 10 digits by padding with zeros (optional)
df["Phone_Number"] = df["Phone_Number"].str.zfill(10)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   0000000000
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger   0000000000
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN   0000000000
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee   0000000000
# 11        1012      Harry      Potter   0000000000
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace("0000000000","")
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x : x[0:3] + "-" + x[3:6] + "-" + x[6:10])
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df[["Address","State","Pin Code"]] = df["Address"].str.split(",",n=2,expand = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes","Y")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes","Y")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN            --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df = df.fillna("")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf                        --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("N/a","")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White            --    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf                        --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# ...

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == "Y":
        df.drop(x,inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 2         1003     Walter       White            --    298 Drugs Driveway
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 6         1007       Jeff      Winger            --     1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf                        --      123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee            --        612 Shire Lane
# 11        1012      Harry      Potter            --  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# ...

# %%
for x in df.index:
    if df.loc[x,"Phone_Number"] == "--":
        df.drop(x,inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017   Michael        Scott  123-643-9775      121 Paper Avenue
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Pin Code
# 0                Y              N          Shire
# 4                Y              N
# ...

# %%
df.reset_index(drop = True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1        1005        Jon        Snow  876-678-3469      123 Dragons Road
# 2        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 3        1010      Peter      Parker  123-545-5421      25th Main Street
# 4        1013        Don      Draper  123-543-2345      2039 Main Street
# 5        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 6        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 7        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 8        1017   Michael        Scott  123-643-9775      121 Paper Avenue
# 9        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#   Paying Customer Do_Not_Contact          State Pin Code
# 0               Y              N          Shire
# 1               Y              N
# ...
